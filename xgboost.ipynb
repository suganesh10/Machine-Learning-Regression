# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/48.9 MB ? eta -:--:--
#    - -------------------------------------- 1.3/48.9 MB 8.5 MB/s eta 0:00:06
#    --- ------------------------------------ 4.7/48.9 MB 14.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.8/48.9 MB 10.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.3/48.9 MB 8.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 7.1/48.9 MB 7.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 7.3/48.9 MB 6.6 MB/s eta 0:00:07
#    ------ --------------------------------- 7.9/48.9 MB 5.4 MB/s eta 0:00:08
#    ------ --------------------------------- 8.4/48.9 MB 5.1 MB/s eta 0:00:08
#    ------- -------------------------------- 9.2/48.9 MB 5.0 MB/s eta 0:00:08
#    -------- ------------------------------- 10.2/48.9 MB 5.0 MB/s eta 0:00:08
#    --------- ------------------------------ 11.5/48.9 MB 5.1 MB/s eta 0:00:08
# ...

# %%
import xgboost

# %%
import pandas as pd

# %%
dataset=read_csv
